# %% [markdown]
# # Question 3
#
# Prior building a Radial Basis Function Kernel Support Vector Machine (RBF SVM), part of the data processing was done on toxicity.xlsx on Excel to limit further processing on Jupyter NoteBook. Namely, I duplicate the label containing 'Neutral' so that it would equal the data sample size of 'Offensive', 'Very offensive', 'Extremely offensive','Profanity','Hate speech' combined while maintaining features distributions.
#
#
# This was done to ensure the RBF SVM did not perform on the basis of Frequency Approach (i.e. predict based on the most common group).
#
# As one can anticipate from the above statements, 'Neutral' is defined as  __'Non-Toxic'__ group while 'offensive', 'Very offensive', 'Extremely offensive','Profanity', 'Hate speech' is defined as  __Toxic__ group.
#
#
# SVM was chosen since it is memory efficient aginst small data samples while it has high accuracy when dealing with classification.

# %%
# %matplotlib notebook
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
# Step 1: Data Exploration

# %%
df = pd.read_excel('toxicity.xlsx')

# %%
df.head(10000)
# Out:
#       Unnamed: 0  flirtation  identity_attack    insult  severe_toxicity  \
# 0              0    0.593828         0.563516  0.849090         0.864632
# 1              1    0.213193         0.407253  0.925010         0.856451
# 2              2    0.474532         0.323574  0.710831         0.747318
# 3              3    0.503426         0.407557  0.796685         0.854638
# 4              4    0.394807         0.170078  0.561849         0.766563
# ...          ...         ...              ...       ...              ...
# 9995        9995    0.336684         0.367809  0.907675         0.854638
# 9996        9996    0.131690         0.751329  0.964347         0.705841
# 9997        9997    0.389191         0.153244  0.682740         0.747318
# 9998        9998    0.232913         0.894221  0.890876         0.837180
# 9999        9999    0.391174         0.877267  0.763176         0.777844
#
#       sexually_explicit    threat                label
# ...

# %%
df.groupby(['label']).count()
# Out:
#                      Unnamed: 0  flirtation  identity_attack  insult  \
# label
# Extremely offensive         426         426              426     426
# Hate speech                  86          86               86      86
# Neutral                   10582       10582            10582   10582
# Offensive                  5966        5966             5966    5966
# Profanity                  3430        3430             3430    3430
# Unknown                     140         140              140     140
# Very offensive             1138        1138             1138    1138
#
#                      severe_toxicity  sexually_explicit  threat
# label
# Extremely offensive              426                426     426
# Hate speech                       86                 86      86
# Neutral                        10582              10582   10582
# Offensive                       5966               5966    5966
# Profanity                       3430               3430    3430
# ...

# %%
# Step 2: Label Classification into either 'Toxic' or 'Non-Toxic' group. 
# Please Note, 'Unknown' is removed.

# %%
df = df.replace(['Offensive', 'Very offensive', 'Extremely offensive','Profanity','Hate speech','Neutral'],[
    'Toxic','Toxic','Toxic','Toxic','Toxic','Non-Toxic'])

# %%
df.count()
# Out:
# Unnamed: 0           21768
# flirtation           21768
# identity_attack      21768
# insult               21768
# severe_toxicity      21768
# sexually_explicit    21768
# threat               21768
# label                21768
# dtype: int64

# %%
df.groupby(['label']).count()
# Out:
#            Unnamed: 0  flirtation  identity_attack  insult  severe_toxicity  \
# label
# Non-Toxic       10582       10582            10582   10582            10582
# Toxic           11046       11046            11046   11046            11046
# Unknown           140         140              140     140              140
#
#            sexually_explicit  threat
# label
# Non-Toxic              10582   10582
# Toxic                  11046   11046
# Unknown                  140     140

# %%
df = df[df.label.isin(['Toxic','Non-Toxic'])]

# %%
df.groupby(['label']).count()
# Out:
#            Unnamed: 0  flirtation  identity_attack  insult  severe_toxicity  \
# label
# Non-Toxic       10582       10582            10582   10582            10582
# Toxic           11046       11046            11046   11046            11046
#
#            sexually_explicit  threat
# label
# Non-Toxic              10582   10582
# Toxic                  11046   11046

# %%
# Step 3: Create Dependent 'y' and Independent Variables 'X'

# %%
X_Independent = df.iloc[:,1:-1]

# %%
X_Independent.head()
# Out:
#    flirtation  identity_attack    insult  severe_toxicity  sexually_explicit  \
# 0    0.593828         0.563516  0.849090         0.864632           0.777347
# 1    0.213193         0.407253  0.925010         0.856451           0.456983
# 2    0.474532         0.323574  0.710831         0.747318           0.933715
# 3    0.503426         0.407557  0.796685         0.854638           0.955973
# 4    0.394807         0.170078  0.561849         0.766563           0.459300
#
#      threat
# 0  0.602494
# 1  0.592931
# 2  0.208848
# 3  0.343336
# 4  0.223698

# %%
Y_dependent = df.iloc[:,-1]

# %%
Y_dependent.head()
# Out:
# 0        Toxic
# 1        Toxic
# 2        Toxic
# 3    Non-Toxic
# 4        Toxic
# Name: label, dtype: object

# %%
# Step 4: Spliting Data into Train and Test Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Independent, Y_dependent, test_size = 0.2, random_state = 0)

# %%
X_train.count()
# Out:
# flirtation           17302
# identity_attack      17302
# insult               17302
# severe_toxicity      17302
# sexually_explicit    17302
# threat               17302
# dtype: int64

# %%
X_test.count()
# Out:
# flirtation           4326
# identity_attack      4326
# insult               4326
# severe_toxicity      4326
# sexually_explicit    4326
# threat               4326
# dtype: int64

# %%
# Step 5: Data Normalisation on Training Data via MinMax Scaler

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Step 6: Grid Search for RBF SVM

# %%
clf = SVC(kernel= 'rbf')
grid_values = {'gamma': [0.001, 0.1, 0.05, 0.1, 1, 10, 100], 'C':[0.1, 1, 15] }

# %%
grid_clf_acc = GridSearchCV(clf, param_grid = grid_values)
grid_clf_acc.fit(X_train_scaled, y_train)
print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)
# Out:
# Grid best parameter (max. accuracy):  {'C': 15, 'gamma': 100}
# Grid best score (accuracy):  0.9815049277414895

# %%
# Step 7: Data Normalisation on Testing Data via MinMax Scaler

# %%
scaler = MinMaxScaler()
X_test_scaled = scaler.fit_transform(X_test)

# %%
# Step 8: Accuracy testing with hyperparameters-tuned SVM on testing data

# %%
SVM_predicted = SVC(gamma = 100, C=15, probability = True).fit(X_train_scaled, y_train) 
SVM_predicted.score(X_test_scaled, y_test)
# Out:
# 0.963245492371706

# %%
# Step 9: Testing SVM Model with ROC

# %%
y_score_SVM = SVC(gamma = 100, C=15,probability = True ).fit(X_train_scaled, y_train).decision_function(X_test_scaled)
y_test = y_test.replace(['Toxic','Non-Toxic'],[1,0])
fpr,tpr, _ = roc_curve(y_test,y_score_SVM)
roc_auc_SVM = auc(fpr,tpr)

# %%
plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr, tpr, lw=3, label='ROC curve (AUC = {:0.2f})'.format(roc_auc_SVM))
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve (RBF SVM)', fontsize=16)
plt.legend(loc='lower right', fontsize=13)
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
plt.axes().set_aspect('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /opt/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# # Conclusion
#
# Overall, I have created an RBF SVM to predict Toxic group from Non-Toxic group. During the Training/GridSearch phase, an accuracy score of __.98%__ was obtained which is hugely encouraging given the score is the average cross-validation accuracy score produced from the internal GridSearch process.
#
# Further accuracy score gained from the Testing phase of __.96%__ further demonstrates the accuracy of the RBF SVM. Receiver Operating Characteristics (ROC) was then utilised to confirm that the RBF SVM model has a high tendency towards the True Positive Rate as the AUC is __.98__ (AUC = 1 (Best), AUC = 0 (Worst)).
#
# In sum, I have built a highly accurate Machine Learning Model to classifier Toxic from Non-Toxic group.
